# %%
lst=[65,98,78,7,9,8]
lst
# Out:
# [65, 98, 78, 7, 9, 8]

# %%
lst[-4:-1]
# Out:
# [78, 7, 9]

# %%
tup=[(78,98,67)]
tup
# Out:
# [(78, 98, 67)]

# %%
data={3,9,2,1}
data
# Out:
# {1, 2, 3, 9}

# %%
lst=[2,74,86,98,78,"a"]
lst_copy=lst
lst_copy.append("89")#this is biggest draw back in list if we add lst_copy it can also take elements to the lst also
lst
# Out:
# [2, 74, 86, 98, 78, 'a', '89']

# %%
lst
lst.append()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 lst
# ----> 2 lst.append()
#
# TypeError: list.append() takes exactly one argument (0 given)

# %%
tup=(3,4,97,98)
a,b,*c=tup

# %%
a
# Out:
# 3

# %%
c
# Out:
# [97, 98]

# %%
lst=[65,98,78,7,9,8]
type(lst)
# Out:
# list

# %%
dict_1={"a":1,"b":2, "c":3}
list(dict_1)
# Out:
# ['a', 'b', 'c']
